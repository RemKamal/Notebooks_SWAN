					"value":0.969,
					"error":0.045
				},
				"pt:[70.00,80.00]":{
					"value":0.945,
					"error":0.078
				},
				"pt:[80.00,100.00]":{
					"value":0.989,
					"error":0.046
				}
			},
			"eta:[-2.17,-1.80]":{
				"pt:[100.00,120.00]":{
					"value":0.987,
					"error":0.022
				},
				"pt:[120.00,200.00]":{
					"value":1.022,
					"error":0.022
				},
				"pt:[20.00,22.00]":{
					"value":0.853,
					"error":0.028
				},
				"pt:[22.00,25.00]":{
					"value":0.869,
					"error":0.025
				},
				"pt:[25.00,30.00]":{
					"value":0.891,
					"error":0.016
				},
				"pt:[30.00,35.00]":{
					"value":0.916,
					"error":0.014
				},
				"pt:[35.00,40.00]":{
					"value":0.935,
					"error":0.009
				},
				"pt:[40.00,50.00]":{
					"value":0.946,
					"error":0.012
				},
				"pt:[50.00,60.00]":{
					"value":0.957,
					"error":0.011
				},
				"pt:[60.00,70.00]":{
					"value":0.955,
					"error":0.054
				},
				"pt:[70.00,80.00]":{
					"value":0.978,
					"error":0.019
				},
				"pt:[80.00,100.00]":{
					"value":0.968,
					"error":0.016
				}
			},
			"eta:[-2.50,-2.17]":{
				"pt:[100.00,120.00]":{
					"value":1.073,
					"error":0.089
				},
				"pt:[120.00,200.00]":{
					"value":1.049,
					"error":0.127
				},
				"pt:[20.00,22.00]":{
					"value":0.879,
					"error":0.039
				},
				"pt:[22.00,25.00]":{
					"value":0.866,
					"error":0.129
				},
				"pt:[25.00,30.00]":{
					"value":0.9,
					"error":0.054
				},
				"pt:[30.00,35.00]":{
					"value":0.933,
					"error":0.022
				},
				"pt:[35.00,40.00]":{
					"value":0.944,
					"error":0.018
				},
				"pt:[40.00,50.00]":{
					"value":0.963,
					"error":0.017
				},
				"pt:[50.00,60.00]":{
					"value":0.967,
					"error":0.044
				},
				"pt:[60.00,70.00]":{
					"value":0.981,
					"error":0.033
				},
				"pt:[70.00,80.00]":{
					"value":1.0,
					"error":0.091
				},
				"pt:[80.00,100.00]":{
					"value":1.02,
					"error":0.039
				}
			}
		}
	}
}

# %%
d1 = EIDISO_ZH_out['EIDISO_ZH']
import pandas as pd
d2 = d1['eta_pt_ratio']
df = pd.DataFrame(d2)
import seaborn as sns
# %matplotlib inline
import numpy as np
idx = [str(i) for i in df.index]
cols = [str(j) for j in df.columns]
df
new_df = pd.DataFrame(index=idx, columns=cols)
new_df
err_df = pd.DataFrame(index=idx, columns=cols)

#df['abseta:[0.0,0.9]']['pt:[20.0,25.0]']['value']
for c in cols:
    for r in idx:
        print ('col={0}, row={1}'.format(c,r))
        #print (df[c][r]['value'])
        new_df[c][r]= round(df[c][r]['value'],3)# + '+/-' + str(
        err_df[c][r] = round(df[c][r]['error'],4)
        #print (new_df[c][r])
        
#plot_df = pd.DataFrame(new_df, index=idx, columns=cols)
#sns.heatmap(plot_df, cmap='RdYlGn_r', linewidths=0.5, annot=True)
#new_df.columns
#new_df.isnull().values.any()
err_df.values
new_df.fillna(value=np.nan, inplace=True)
err_df.fillna(value=np.nan, inplace=True)

import matplotlib.pyplot as plt
import matplotlib

sns.set(style="white", palette="muted", color_codes=True)
rs = np.random.RandomState(10)

# Set up the matplotlib figure
f, axes = plt.subplots(1, 1, figsize=(16, 16), sharex=True)
sns.despine(left=True)

# Generate a random univariate dataset
#d = rs.normal(size=100)

# Plot a simple histogram with binsize determined automatically
#sns.distplot(, kde=False, color="b", ax=axes[0, 0])

annot_kws = {"ha": 'center',"va": 'top'}
annot_kws_err = {"ha": 'center',"va": 'bottom'}

#sns.heatmap(err_df, cmap='Blues', linewidths=0.2, annot=True, fmt='.2g', annot_kws=annot_kws)
strings = np.asarray([['a', 'b', 'c', 'd'],
                                ['d', 'e', 'f', 'n'],
                                ['g', 'h', 'i', 'e'],
                                ['j', 'k', 'l', 'r'],
                                 ['g', 'h', 'i', 'e'],
                                ['j', 'k', 'l', 'r']])

labels = (np.asarray(["{0:.3f}\n+/-\n{1:.3f}".format(string, value)
                      for string, value in zip(new_df.values.flatten(), #strings.flatten(),
                                               err_df.values.flatten())])
         ).reshape(12, 12)

#fig, ax = plt.subplots()
sns.heatmap(new_df, annot=labels, fmt="", cmap='Blues', ax=axes)
#sns.heatmap(new_df, cmap='Blues', linewidths=0.2, annot=True, fmt='g', annot_kws=annot_kws_err)

#for t in axes.texts:
 #   trans = t.get_transform()https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-041sc-probabilistic-systems-analysis-and-applied-probability-fall-2013/unit-ii/lecture-12/MIT6_041SCF13_rec13_sol.pdf
  #  offs = matplotlib.transforms.ScaledTranslation(-0., 0.,
   #                 matplotlib.transforms.IdentityTransform())https://ocw.mit.edu/courses/electrical-engineering-and-computer-science/6-041sc-probabilistic-systems-analysis-and-applied-probability-fall-2013/unit-ii/lecture-12/MIT6_041SCF13_rec13_sol.pdf
    #t.set_transform( offs + trans )

#plt.show()

plt.setp(axes)
plt.tight_layout()
# Out:
# col=eta:[ 0.00, 0.80], row=pt:[100.00,120.00]
# col=eta:[ 0.00, 0.80], row=pt:[120.00,200.00]
# col=eta:[ 0.00, 0.80], row=pt:[20.00,22.00]
# col=eta:[ 0.00, 0.80], row=pt:[22.00,25.00]
# col=eta:[ 0.00, 0.80], row=pt:[25.00,30.00]
# col=eta:[ 0.00, 0.80], row=pt:[30.00,35.00]
# col=eta:[ 0.00, 0.80], row=pt:[35.00,40.00]
# col=eta:[ 0.00, 0.80], row=pt:[40.00,50.00]
# col=eta:[ 0.00, 0.80], row=pt:[50.00,60.00]
# col=eta:[ 0.00, 0.80], row=pt:[60.00,70.00]
# col=eta:[ 0.00, 0.80], row=pt:[70.00,80.00]
# col=eta:[ 0.00, 0.80], row=pt:[80.00,100.00]
# col=eta:[ 0.80, 1.44], row=pt:[100.00,120.00]
# col=eta:[ 0.80, 1.44], row=pt:[120.00,200.00]
# col=eta:[ 0.80, 1.44], row=pt:[20.00,22.00]
# col=eta:[ 0.80, 1.44], row=pt:[22.00,25.00]
# col=eta:[ 0.80, 1.44], row=pt:[25.00,30.00]
# col=eta:[ 0.80, 1.44], row=pt:[30.00,35.00]
# col=eta:[ 0.80, 1.44], row=pt:[35.00,40.00]
# col=eta:[ 0.80, 1.44], row=pt:[40.00,50.00]
# col=eta:[ 0.80, 1.44], row=pt:[50.00,60.00]
# ...
