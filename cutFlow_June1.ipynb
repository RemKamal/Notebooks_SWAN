# %%
import pandas as pd
import numpy as np

# %%
dict_effs_muons_VTC_BulkGraviton={'DY1J': [417338.0,
          417338.0,
          110547.0,
          85607.0,
          56342.0,
          56342.0,
          51277.0,
          39117.0,
          39117.0,
          39117.0,
          36405.0,
          157.0,
          157.0,
          157.0,
          150.0,
          150.0,
          150.0,
          50.0,
          48.0],
 'DY2J': [1420203.0,
          1420203.0,
          611691.0,
          580244.0,
          500832.0,
          500832.0,
          454996.0,
          370082.0,
          370082.0,
          370082.0,
          345352.0,
          3310.0,
          3310.0,
          3310.0,
          3194.0,
          3194.0,
          3194.0,
          1149.0,
          1112.0],
 'TT': [10256777.0,
        10256777.0,
        2305783.0,
        591613.0,
        312790.0,
        312790.0,
        286041.0,
        221047.0,
        221047.0,
        221047.0,
        208207.0,
        83475.0,
        83470.0,
        83470.0,
        63313.0,
        63313.0,
        63313.0,
        19545.0,
        6974.0],
 'bbWW300': [105676.0,
             98742.0,
             38415.0,
             16061.0,
             8283.0,
             8283.0,
             7801.0,
             6832.0,
             6832.0,
             6832.0,
             6386.0,
             2808.0,
             2808.0,
             2808.0,
             98.0,
             98.0,
             98.0,
             87.0,
             85.0],
 'bbWW900': [68455.0,
             64697.0,
             22815.0,
             12209.0,
             3598.0,
             3598.0,
             3330.0,
             2390.0,
             2390.0,
             2390.0,
             2260.0,
             843.0,
             843.0,
             843.0,
             29.0,
             29.0,
             29.0,
             23.0,
             23.0],
 'bbZZ300': [84853.0,
             84853.0,
             43332.0,
             37879.0,
             26708.0,
             26708.0,
             24556.0,
             18637.0,
             18637.0,
             18637.0,
             17628.0,
             6682.0,
             6682.0,
             6682.0,
             5711.0,
             5711.0,
             5711.0,
             4512.0,
             4511.0],
 'bbZZ900': [171922.0,
             171922.0,
             85786.0,
             72024.0,
             54262.0,
             54262.0,
             51253.0,
             45963.0,
             45963.0,
             45963.0,
             43031.0,
             18707.0,
             18707.0,
             18707.0,
             15561.0,
             15561.0,
             15561.0,
             12972.0,
             12963.0]}
names = ['no cut', 'splitSignal', 'inclusive >=2 ee/mm', 'selLeptons pdg ID 11/13', 'mva ID', 'ocsf and leading pt', 'eta gap',
                 'iso cut', 'manual preselection', '0 or 1 vType', 'trigger', '>=2b-jets', 'Hbb loose',  '2leps', 'Z mass loose',
                 'met>0', 'hhMt>100', '90<Hbb<150', '76<Z<106']


df = pd.DataFrame.from_dict(dict_effs_muons_VTC_BulkGraviton, orient='index')
df.columns=names
df.round(1)


df_renorm = df.drop(columns=['no cut', 'splitSignal', 'ocsf and leading pt', 'manual preselection', '0 or 1 vType', 'Hbb loose',  '2leps', 'met>0', 'hhMt>100',
                            '>=2b-jets', '90<Hbb<150', 'Z mass loose'],                   
                   index=['DY1J', 'DY2J', 'TT'])
df_renorm = df_renorm.div(df_renorm['inclusive >=2 ee/mm'], axis=0)
df_renorm = df_renorm.multiply(100) # * 100
df_renorm.rename(columns={'eta gap': 'leading pt and eta gap', 'inclusive >=2 ee/mm':'2 very loose muons', 
                         'selLeptons pdg ID 11/13':'2 loose muons',
                         'iso cut':'iso<0.15',
                         '76<Z<106':'>=2b-jets, Hbb and Zll cuts'}, inplace=True)
df_renorm.round(1)
# Out:
#          2 very loose muons  2 loose muons  mva ID  leading pt and eta gap  \
# bbWW300               100.0           41.8    21.6                    20.3
# bbZZ300               100.0           87.4    61.6                    56.7
# bbWW900               100.0           53.5    15.8                    14.6
# bbZZ900               100.0           84.0    63.3                    59.7
#
#          iso<0.15  trigger  >=2b-jets, Hbb and Zll cuts
# bbWW300      17.8     16.6                          0.2
# bbZZ300      43.0     40.7                         10.4
# bbWW900      10.5      9.9                          0.1
# bbZZ900      53.6     50.2                         15.1

# %%
dict_effs_eles_VTC_BulkGraviton={'DY1J': [417338.0,
          417338.0,
          124958.0,
          48710.0,
          35361.0,
          34981.0,
          33385.0,
          18948.0,
          18948.0,
          18948.0,
          17795.0,
          64.0,
          64.0,
          64.0,
          62.0,
          62.0,
          62.0,
          25.0,
          23.0],
 'DY2J': [1420203.0,
          1420203.0,
          491662.0,
          374961.0,
          293198.0,
          290953.0,
          278451.0,
          195288.0,
          195288.0,
          195287.0,
          183634.0,
          1591.0,
          1591.0,
          1591.0,
          1546.0,
          1546.0,
          1546.0,
          608.0,
          590.0],
 'TT': [10256777.0,
        10256777.0,
        3615118.0,
        582827.0,
        257932.0,
        255764.0,
        242261.0,
        144412.0,
        144412.0,
        144408.0,
        135110.0,
        53873.0,
        53871.0,
        53871.0,
        42488.0,
        42488.0,
        42488.0,
        13295.0,
        4340.0],
 'bbWW300': [105676.0,
             98742.0,
             43909.0,
             17036.0,
             8304.0,
             8148.0,
             7651.0,
             5695.0,
             5695.0,
             5695.0,
             4388.0,
             1896.0,
             1896.0,
             1896.0,
             62.0,
             62.0,
             62.0,
             57.0,
             53.0],
 'bbWW900': [68455.0,
             64697.0,
             28902.0,
             11127.0,
             4316.0,
             4119.0,
             3786.0,
             1595.0,
             1595.0,
             1595.0,
             1385.0,
             503.0,
             503.0,
             503.0,
             14.0,
             14.0,
             14.0,
             12.0,
             12.0],
 'bbZZ300': [84853.0,
             84853.0,
             38429.0,
             26222.0,
             17807.0,
             17630.0,
             16869.0,
             9483.0,
             9483.0,
             9483.0,
             8876.0,
             3295.0,
             3295.0,
             3295.0,
             2848.0,
             2848.0,
             2848.0,
             2261.0,
             2256.0],
 'bbZZ900': [171922.0,
             171922.0,
             80305.0,
             57377.0,
             36978.0,
             36771.0,
             35104.0,
             28902.0,
             28902.0,
             28902.0,
             27207.0,
             11675.0,
             11675.0,
             11675.0,
             9517.0,
             9517.0,
             9517.0,
             8041.0,
             8034.0]}
names = ['no cut', 'splitSignal', 'inclusive >=2 ee/mm', 'selLeptons pdg ID 11/13', 'mva ID', 'ocsf and leading pt', 'eta gap',
                 'iso cut', 'manual preselection', '0 or 1 vType', 'trigger', '>=2b-jets', 'Hbb loose',  '2leps', 'Z mass loose',
                 'met>0', 'hhMt>100', '90<Hbb<150', '76<Z<106']


df = pd.DataFrame.from_dict(dict_effs_eles_VTC_BulkGraviton, orient='index')
df.columns=names
df.round(1)

df_renorm = df.drop(columns=['no cut', 'splitSignal', 'ocsf and leading pt', 'manual preselection', '0 or 1 vType', 'Hbb loose',  '2leps', 'met>0', 'hhMt>100',
                             '>=2b-jets', '90<Hbb<150', 'Z mass loose'], 
                   index=['DY1J', 'DY2J', 'TT'])
df_renorm = df_renorm.div(df_renorm['inclusive >=2 ee/mm'], axis=0)
df_renorm = df_renorm.multiply(100) # * 100
df_renorm.rename(columns={'eta gap': 'leading pt and eta gap', 'inclusive >=2 ee/mm':'2 very loose electrons', 
                         'selLeptons pdg ID 11/13':'2 loose electrons',
                         'iso cut':'iso<0.06',
                         '76<Z<106':'>=2b-jets, Hbb and Zll cuts'}, inplace=True)
df_renorm.round(1)
# Out:
#          2 very loose electrons  2 loose electrons  mva ID  \
# bbWW300                   100.0               38.8    18.9
# bbZZ300                   100.0               68.2    46.3
# bbWW900                   100.0               38.5    14.9
# bbZZ900                   100.0               71.4    46.0
#
#          leading pt and eta gap  iso<0.06  trigger  \
# bbWW300                    17.4      13.0     10.0
# bbZZ300                    43.9      24.7     23.1
# bbWW900                    13.1       5.5      4.8
# bbZZ900                    43.7      36.0     33.9
#
#          >=2b-jets, Hbb and Zll cuts
# bbWW300                          0.1
# bbZZ300                          5.9
# bbWW900                          0.0
# bbZZ900                         10.0

# %%
from array import array
mass = array('d', [250.0, 260.0, 270.0, 300.0, 350.0, 400.0, 451.0, 500.0, 550.0, 600.0, 650.0, 700.0, 750.0, 800.0, 900.0, 1000.0])

obs = array('d', [273.96720921525264, 304.38708026654797, 249.22172753331952, 308.3543052059407, 156.64814991155032, 148.905298474117, 50.412684917227615, 29.751009164836884, 19.289506980672414, 18.873563212557237, 14.248311376329802, 14.032075259014606, 12.613618059130685, 8.749763475421801, 6.531077322553249, 3.1900314391963587])

for m, o in zip(mass, obs):
    print (m, o)
print len (mass)
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(mass, obs)
# Out:
# (250.0, 273.96720921525264)
# (260.0, 304.38708026654797)
# (270.0, 249.22172753331952)
# (300.0, 308.3543052059407)
# (350.0, 156.64814991155032)
# (400.0, 148.905298474117)
# (451.0, 50.412684917227615)
# (500.0, 29.751009164836884)
# (550.0, 19.289506980672414)
# (600.0, 18.873563212557237)
# (650.0, 14.248311376329802)
# (700.0, 14.032075259014606)
# (750.0, 12.613618059130685)
# (800.0, 8.749763475421801)
# (900.0, 6.531077322553249)
# (1000.0, 3.1900314391963587)
# 16

# %%
dict_effs_eles={'DY2J': [100.0,
          100.0,
          17.7236634481127,
          16.64276163337213,
          0.1475845354502138,
          0.1475845354502138,
          0.1475845354502138,
          0.1423740127291662,
          0.1423740127291662,
          0.1423740127291662,
          0.11047716418005031],
 'TT': [100.0,
        100.0,
        2.51463983276618,
        2.1268279499495795,
        0.8186782261133297,
        0.8186197282050687,
        0.8186197282050687,
        0.608232001144219,
        0.608232001144219,
        0.608232001144219,
        0.4321142986729652],
 'bbWW300': [100.0,
             93.43843446004769,
             3.958325447594534,
             3.793671221469397,
             1.6247776221658654,
             1.6247776221658654,
             1.6247776221658654,
             0.06245505128884515,
             0.06245505128884515,
             0.06245505128884515,
             0.052992164729929216],
 'bbWW900': [100.0,
             94.51026221605434,
             2.579796946899423,
             2.3913519830545615,
             0.8618800671974289,
             0.8618800671974289,
             0.8618800671974289,
             0.027755459791103644,
             0.027755459791103644,
             0.027755459791103644,
             0.02191220509823972],
 'bbZZ300': [100.0,
             100.0,
             16.429589996818027,
             15.3300413656559,
             5.555490082849163,
             5.554311574134091,
             5.554311574134091,
             4.802423013918188,
             4.802423013918188,
             4.802423013918188,
             3.506063427339045],
 'bbZZ900': [100.0,
             100.0,
             16.935587068554344,
             16.38359255941648,
             7.018298996056351,
             7.018298996056351,
             7.018298996056351,
             5.899186840543968,
             5.899186840543968,
             5.899186840543968,
             5.283209827712567]}

names = [
            "skimming",
            "splitSignal",
            #"VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_eles, orient='index')
df.columns=names
df.round(1)
#https://stackoverflow.com/questions/38103467/rescaling-to-0-1-certain-columns-from-pandas-python-dataframe
#https://stackoverflow.com/questions/35678874/normalize-rows-of-pandas-data-frame-by-their-sums
#df_renorm = df/
#df['decayType']#.astype(np.float64)
#df['new denominator'] = df['skimming'] * 
inclusiveElectrons_inNewSample_bbZZ300 = 38429./84853 # damn dot is VERY important HERE!
inclusiveElectrons_inNewSample_bbZZ900 = 80305./171922 # damn dot is VERY important HERE!
df.loc['bbZZ300']['splitSignal'] *= inclusiveElectrons_inNewSample_bbZZ300
df.loc['bbZZ900']['splitSignal'] *= inclusiveElectrons_inNewSample_bbZZ900
df_renorm = df.drop(columns=[ ], 
                   index=['DY2J', 'TT', 'bbWW300', 'bbWW900'])
#df_renorm = df_renorm.div(df_renorm['splitSignal'], axis=0)
#df_renorm = df_renorm.multiply(100) # * 100
#df_renorm.rename(columns={'eta gap': 'leading pt and eta gap', 'inclusive >=2 ee/mm':'2 very loose muons', 
 #                        'selLeptons pdg ID 11/13':'2 loose muons',
  #                       'iso cut':'iso<0.15'}, inplace=True)
df_renorm.round(1)
df_renorm
# Out:
#          skimming  splitSignal  decayType    trigger  >=b-jets  Hbb mass  \
# bbZZ300     100.0    45.288911  16.429590  15.330041  5.555490  5.554312
# bbZZ900     100.0    46.710136  16.935587  16.383593  7.018299  7.018299
#
#          2 leptons    Z mass   MET cut  hhMt cut  analysis cuts
# bbZZ300   5.554312  4.802423  4.802423  4.802423       3.506063
# bbZZ900   7.018299  5.899187  5.899187  5.899187       5.283210

# %%
METcut = 'met75'
METcut = (METcut.strip("met"))
METcut.isdigit()
# Out:
# True
