# %%
import pandas as pd
import numpy as np

# %%
dict_effs_eles={'DY2J': [100.0,
          100.0,
          17.7236634481127,
          16.64276163337213,
          0.1475845354502138,
          0.1475845354502138,
          0.1475845354502138,
          0.1423740127291662,
          0.1423740127291662,
          0.1423740127291662,
          0.11047716418005031],
 'TT': [100.0,
        100.0,
        2.51463983276618,
        2.1268279499495795,
        0.8186782261133297,
        0.8186197282050687,
        0.8186197282050687,
        0.608232001144219,
        0.608232001144219,
        0.608232001144219,
        0.4321142986729652],
 'bbWW300': [100.0,
             93.43843446004769,
             3.958325447594534,
             3.793671221469397,
             1.6247776221658654,
             1.6247776221658654,
             1.6247776221658654,
             0.06245505128884515,
             0.06245505128884515,
             0.06245505128884515,
             0.052992164729929216],
 'bbWW900': [100.0,
             94.51026221605434,
             2.579796946899423,
             2.3913519830545615,
             0.8618800671974289,
             0.8618800671974289,
             0.8618800671974289,
             0.027755459791103644,
             0.027755459791103644,
             0.027755459791103644,
             0.02191220509823972],
 'bbZZ300': [100.0,
             100.0,
             16.429589996818027,
             15.3300413656559,
             5.555490082849163,
             5.554311574134091,
             5.554311574134091,
             4.802423013918188,
             4.802423013918188,
             4.802423013918188,
             3.506063427339045],
 'bbZZ900': [100.0,
             100.0,
             16.935587068554344,
             16.38359255941648,
             7.018298996056351,
             7.018298996056351,
             7.018298996056351,
             5.899186840543968,
             5.899186840543968,
             5.899186840543968,
             5.283209827712567]}

names = [
            "skimming",
            "splitSignal",
            #"VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_eles, orient='index')
df.columns=names
df.round(2)
#https://stackoverflow.com/questions/38103467/rescaling-to-0-1-certain-columns-from-pandas-python-dataframe
#https://stackoverflow.com/questions/35678874/normalize-rows-of-pandas-data-frame-by-their-sums
#df_renorm = df/
#df['decayType']#.astype(np.float64)
df_renorm = df.drop(columns=['skimming', 'splitSignal'])

df_renorm = df_renorm.div(df_renorm['decayType'], axis=0)
df_renorm.round(2)
# Out:
#          skimming  splitSignal  decayType    trigger  >=b-jets  Hbb mass  \
# bbWW900     100.0    94.510262   2.579797   2.391352  0.861880  0.861880
# DY2J        100.0   100.000000  17.723663  16.642762  0.147585  0.147585
# TT          100.0   100.000000   2.514640   2.126828  0.818678  0.818620
# bbWW300     100.0    93.438434   3.958325   3.793671  1.624778  1.624778
# bbZZ300     100.0   100.000000  16.429590  15.330041  5.555490  5.554312
# bbZZ900     100.0   100.000000  16.935587  16.383593  7.018299  7.018299
#
#          2 leptons    Z mass   MET cut  hhMt cut  analysis cuts
# bbWW900   0.861880  0.027755  0.027755  0.027755       0.021912
# DY2J      0.147585  0.142374  0.142374  0.142374       0.110477
# TT        0.818620  0.608232  0.608232  0.608232       0.432114
# bbWW300   1.624778  0.062455  0.062455  0.062455       0.052992
# bbZZ300   5.554312  4.802423  4.802423  4.802423       3.506063
# bbZZ900   7.018299  5.899187  5.899187  5.899187       5.283210

# %%
dict_effs_eles_VTC={'DY1J': [100.0,
          100.0,
          21.93330106532355,
          8.429618199157517,
          7.1987214200480185,
          0.026357532743244084,
          0.026117918809214595,
          0.026117918809214595,
          0.023721779468919676,
          0.023721779468919676,
          0.023721779468919676,
          0.01845027292027086],
 'DY2J': [100.0,
          100.0,
          55.83032848121008,
          20.565510705159756,
          18.60515715006939,
          0.16455394052822025,
          0.16455394052822025,
          0.16455394052822025,
          0.15863929311513916,
          0.15863929311513916,
          0.15863929311513916,
          0.1277986316040735],
 'TT': [100.0,
        100.0,
        5.564233286928243,
        2.51463983276618,
        2.1268279499495795,
        0.8186782261133297,
        0.8186197282050687,
        0.8186197282050687,
        0.6086707354561769,
        0.6086707354561769,
        0.6086707354561769,
        0.4682270073727839],
 'bbWW300': [100.0,
             93.43843446004769,
             15.54941519361066,
             7.711306256860593,
             5.696657708467391,
             2.4366932889208526,
             2.4366932889208526,
             2.4366932889208526,
             0.08232711306256861,
             0.08232711306256861,
             0.08232711306256861,
             0.06150876263295356],
 'bbWW900': [100.0,
             94.51026221605434,
             11.335914104156014,
             6.079906507924914,
             4.557738660433862,
             1.5630706303411,
             1.5630706303411,
             1.5630706303411,
             0.04236359652326346,
             0.04236359652326346,
             0.04236359652326346,
             0.026294646117887663],
 'bbZZ300': [100.0,
             100.0,
             52.30693080975334,
             20.83132004761175,
             18.057110532332388,
             6.439371619153124,
             6.438193110438052,
             6.438193110438052,
             5.359857636147219,
             5.359857636147219,
             5.359857636147219,
             4.116530941746314],
 'bbZZ900': [100.0,
             100.0,
             52.95075673852096,
             21.388769325624413,
             19.452426100208235,
             8.325287048777934,
             8.325287048777934,
             8.325287048777934,
             6.483754260653087,
             6.483754260653087,
             6.483754260653087,
             5.728179057944882]}

names = [
            "skimming",
            "splitSignal",
            "VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_eles_VTC, orient='index')
df.columns=names
df.round(2)
#df_renorm = df.drop(columns=['skimming', 'splitSignal', 'VHbb preselection'])
df_renorm = df.drop(columns=['skimming', 'splitSignal', 'MET cut'],
                   index=['DY1J', 'DY2J', 'TT', 'bbWW300', 'bbWW900'])
#df_renorm = df_renorm.div(df_renorm['decayType'], axis=0)
df_renorm = df_renorm.div(df_renorm['VHbb preselection'], axis=0)
df_renorm.rename(columns={'VHbb preselection':'leptonic decays', 'decayType':'ee channel'}, inplace=True)
df_renorm.round(3)
df
# Out:
#          skimming  splitSignal  VHbb preselection  decayType    trigger  \
# DY1J        100.0   100.000000          21.933301   8.429618   7.198721
# DY2J        100.0   100.000000          55.830328  20.565511  18.605157
# TT          100.0   100.000000           5.564233   2.514640   2.126828
# bbWW300     100.0    93.438434          15.549415   7.711306   5.696658
# bbZZ300     100.0   100.000000          52.306931  20.831320  18.057111
# bbWW900     100.0    94.510262          11.335914   6.079907   4.557739
# bbZZ900     100.0   100.000000          52.950757  21.388769  19.452426
#
#          >=b-jets  Hbb mass  2 leptons    Z mass   MET cut  hhMt cut  \
# DY1J     0.026358  0.026118   0.026118  0.023722  0.023722  0.023722
# DY2J     0.164554  0.164554   0.164554  0.158639  0.158639  0.158639
# TT       0.818678  0.818620   0.818620  0.608671  0.608671  0.608671
# bbWW300  2.436693  2.436693   2.436693  0.082327  0.082327  0.082327
# ...

# %%
dict_effs_muons_eleCuts={'DY2J': [100.0,
          100.0,
          35.26481777605033,
          32.91958966429447,
          0.31023733930994374,
          0.3101669268407404,
          0.3101669268407404,
          0.2980559821377648,
          0.2980559821377648,
          0.2980559821377648,
          0.18905747981098478],
 'TT': [100.0,
        100.0,
        3.049593454162063,
        2.8650325535984646,
        1.1294776127042638,
        1.1294191147960027,
        1.1294191147960027,
        0.8344824109951888,
        0.8344824109951888,
        0.8344824109951888,
        0.5070403695039875],
 'bbWW300': [100.0,
             93.43843446004769,
             7.838108936750066,
             7.307241000794883,
             3.140732048904198,
             3.140732048904198,
             3.140732048904198,
             0.10882319542753321,
             0.10882319542753321,
             0.10882319542753321,
             0.08138082440667702],
 'bbWW900': [100.0,
             94.51026221605434,
             5.2560075962311,
             4.949236724855744,
             1.8260170915199767,
             1.8260170915199767,
             1.8260170915199767,
             0.05551091958220729,
             0.05551091958220729,
             0.05551091958220729,
             0.03359871448396757],
 'bbZZ300': [100.0,
             100.0,
             31.475610762141585,
             29.706669180818594,
             11.072089378100952,
             11.072089378100952,
             11.072089378100952,
             9.364430249961698,
             9.364430249961698,
             9.364430249961698,
             5.295039656818262],
 'bbZZ900': [100.0,
             100.0,
             31.561987412896546,
             29.588999662637708,
             12.79417410220914,
             12.79417410220914,
             12.79417410220914,
             10.579797815288329,
             10.579797815288329,
             10.579797815288329,
             8.443945510173219]}

names = [
            "skimming",
            "splitSignal",
            #"VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_muons_eleCuts, orient='index')
df.columns=names
df.round(2)
# Out:
#          skimming  splitSignal  decayType  trigger  >=b-jets  Hbb mass  \
# bbWW900     100.0        94.51       5.26     4.95      1.83      1.83
# DY2J        100.0       100.00      35.26    32.92      0.31      0.31
# TT          100.0       100.00       3.05     2.87      1.13      1.13
# bbWW300     100.0        93.44       7.84     7.31      3.14      3.14
# bbZZ300     100.0       100.00      31.48    29.71     11.07     11.07
# bbZZ900     100.0       100.00      31.56    29.59     12.79     12.79
#
#          2 leptons  Z mass  MET cut  hhMt cut  analysis cuts
# bbWW900       1.83    0.06     0.06      0.06           0.03
# DY2J          0.31    0.30     0.30      0.30           0.19
# TT            1.13    0.83     0.83      0.83           0.51
# bbWW300       3.14    0.11     0.11      0.11           0.08
# bbZZ300      11.07    9.36     9.36      9.36           5.30
# bbZZ900      12.79   10.58    10.58     10.58           8.44

# %%
dict_effs_muons_METcut={'DY2J': [100.0,
          100.0,
          35.26481777605033,
          32.91958966429447,
          0.31023733930994374,
          0.3101669268407404,
          0.3101669268407404,
          0.2980559821377648,
          0.2980559821377648,
          0.2980559821377648,
          0.25616056296177375],
 'TT': [100.0,
        100.0,
        3.049593454162063,
        2.8650325535984646,
        1.1294776127042638,
        1.1294191147960027,
        1.1294191147960027,
        0.8344824109951888,
        0.8344824109951888,
        0.8344824109951888,
        0.6998787240865235],
 'bbWW300': [100.0,
             93.43843446004769,
             7.838108936750066,
             7.307241000794883,
             3.140732048904198,
             3.140732048904198,
             3.140732048904198,
             0.10882319542753321,
             0.10882319542753321,
             0.10882319542753321,
             0.060562473977061965],
 'bbWW900': [100.0,
             94.51026221605434,
             5.2560075962311,
             4.949236724855744,
             1.8260170915199767,
             1.8260170915199767,
             1.8260170915199767,
             0.05551091958220729,
             0.05551091958220729,
             0.05551091958220729,
             0.029216273464319625],
 'bbZZ300': [100.0,
             100.0,
             31.475610762141585,
             29.706669180818594,
             11.072089378100952,
             11.072089378100952,
             11.072089378100952,
             9.364430249961698,
             9.364430249961698,
             9.364430249961698,
             3.6521985080079666],
 'bbZZ900': [100.0,
             100.0,
             31.561987412896546,
             29.588999662637708,
             12.79417410220914,
             12.79417410220914,
             12.79417410220914,
             10.579797815288329,
             10.579797815288329,
             10.579797815288329,
             4.474121985551587]}
names = [
            "skimming",
            "splitSignal",
            #"VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_muons_METcut, orient='index')
df.columns=names
df.round(2)
# Out:
#          skimming  splitSignal  decayType  trigger  >=b-jets  Hbb mass  \
# bbWW900     100.0        94.51       5.26     4.95      1.83      1.83
# DY2J        100.0       100.00      35.26    32.92      0.31      0.31
# TT          100.0       100.00       3.05     2.87      1.13      1.13
# bbWW300     100.0        93.44       7.84     7.31      3.14      3.14
# bbZZ300     100.0       100.00      31.48    29.71     11.07     11.07
# bbZZ900     100.0       100.00      31.56    29.59     12.79     12.79
#
#          2 leptons  Z mass  MET cut  hhMt cut  analysis cuts
# bbWW900       1.83    0.06     0.06      0.06           0.03
# DY2J          0.31    0.30     0.30      0.30           0.26
# TT            1.13    0.83     0.83      0.83           0.70
# bbWW300       3.14    0.11     0.11      0.11           0.06
# bbZZ300      11.07    9.36     9.36      9.36           3.65
# bbZZ900      12.79   10.58    10.58     10.58           4.47

# %%
dict_effs_eles_VTC_METcut={'DY1J': [100.0,
          100.0,
          21.93330106532355,
          8.429618199157517,
          7.1987214200480185,
          0.026357532743244084,
          0.026117918809214595,
          0.026117918809214595,
          0.023721779468919676,
          0.023721779468919676,
          0.023721779468919676,
          0.01845027292027086],
 'DY2J': [100.0,
          100.0,
          55.83032848121008,
          20.565510705159756,
          18.60515715006939,
          0.16455394052822025,
          0.16455394052822025,
          0.16455394052822025,
          0.15863929311513916,
          0.15863929311513916,
          0.15863929311513916,
          0.1277986316040735],
 'TT': [100.0,
        100.0,
        5.564233286928243,
        2.51463983276618,
        2.1268279499495795,
        0.8186782261133297,
        0.8186197282050687,
        0.8186197282050687,
        0.6086707354561769,
        0.6086707354561769,
        0.6086707354561769,
        0.4682270073727839],
 'bbWW300': [100.0,
             93.43843446004769,
             15.54941519361066,
             7.711306256860593,
             5.696657708467391,
             2.4366932889208526,
             2.4366932889208526,
             2.4366932889208526,
             0.08232711306256861,
             0.08232711306256861,
             0.08232711306256861,
             0.03595896892388054],
 'bbWW900': [100.0,
             94.51026221605434,
             11.335914104156014,
             6.079906507924914,
             4.557738660433862,
             1.5630706303411,
             1.5630706303411,
             1.5630706303411,
             0.04236359652326346,
             0.04236359652326346,
             0.04236359652326346,
             0.016068950405375794],
 'bbZZ300': [100.0,
             100.0,
             52.30693080975334,
             20.83132004761175,
             18.057110532332388,
             6.439371619153124,
             6.438193110438052,
             6.438193110438052,
             5.359857636147219,
             5.359857636147219,
             5.359857636147219,
             1.9881442023263762],
 'bbZZ900': [100.0,
             100.0,
             52.95075673852096,
             21.388769325624413,
             19.452426100208235,
             8.325287048777934,
             8.325287048777934,
             8.325287048777934,
             6.483754260653087,
             6.483754260653087,
             6.483754260653087,
             2.6837752003815685]}
names = [
            "skimming",
            "splitSignal",
            "VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_eles_VTC_METcut, orient='index')
df.columns=names
df.round(2)
# Out:
#          skimming  splitSignal  VHbb preselection  decayType  trigger  \
# DY1J        100.0       100.00              21.93       8.43     7.20
# DY2J        100.0       100.00              55.83      20.57    18.61
# TT          100.0       100.00               5.56       2.51     2.13
# bbWW300     100.0        93.44              15.55       7.71     5.70
# bbZZ300     100.0       100.00              52.31      20.83    18.06
# bbWW900     100.0        94.51              11.34       6.08     4.56
# bbZZ900     100.0       100.00              52.95      21.39    19.45
#
#          >=b-jets  Hbb mass  2 leptons  Z mass  MET cut  hhMt cut  \
# DY1J         0.03      0.03       0.03    0.02     0.02      0.02
# DY2J         0.16      0.16       0.16    0.16     0.16      0.16
# TT           0.82      0.82       0.82    0.61     0.61      0.61
# bbWW300      2.44      2.44       2.44    0.08     0.08      0.08
# bbZZ300      6.44      6.44       6.44    5.36     5.36      5.36
# ...

# %%
dict_effs_muons={'DY2J': [100.0,
          100.0,
          35.26481777605033,
          32.91958966429447,
          0.31023733930994374,
          0.3101669268407404,
          0.3101669268407404,
          0.2980559821377648,
          0.2980559821377648,
          0.2980559821377648,
          0.25616056296177375],
 'TT': [100.0,
        100.0,
        3.049593454162063,
        2.8650325535984646,
        1.1294776127042638,
        1.1294191147960027,
        1.1294191147960027,
        0.8344824109951888,
        0.8344824109951888,
        0.8344824109951888,
        0.6998787240865235],
 'bbWW300': [100.0,
             93.43843446004769,
             7.838108936750066,
             7.307241000794883,
             3.140732048904198,
             3.140732048904198,
             3.140732048904198,
             0.10882319542753321,
             0.10882319542753321,
             0.10882319542753321,
             0.0955751542450509],
 'bbWW900': [100.0,
             94.51026221605434,
             5.2560075962311,
             4.949236724855744,
             1.8260170915199767,
             1.8260170915199767,
             1.8260170915199767,
             0.05551091958220729,
             0.05551091958220729,
             0.05551091958220729,
             0.04820685121612738],
 'bbZZ300': [100.0,
             100.0,
             31.475610762141585,
             29.706669180818594,
             11.072089378100952,
             11.072089378100952,
             11.072089378100952,
             9.364430249961698,
             9.364430249961698,
             9.364430249961698,
             7.79229962405572],
 'bbZZ900': [100.0,
             100.0,
             31.561987412896546,
             29.588999662637708,
             12.79417410220914,
             12.79417410220914,
             12.79417410220914,
             10.579797815288329,
             10.579797815288329,
             10.579797815288329,
             9.635183397121951]}
names = [
            "skimming",
            "splitSignal",
            #"VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_muons, orient='index')
df.columns=names
df.round(2)
df_renorm = df.drop(columns=['skimming', 'splitSignal'])

df_renorm = df_renorm.div(df_renorm['decayType'], axis=0)
df_renorm.round(2)
# Out:
#          decayType  trigger  >=b-jets  Hbb mass  2 leptons  Z mass  MET cut  \
# bbWW900        1.0     0.94      0.35      0.35       0.35    0.01     0.01
# DY2J           1.0     0.93      0.01      0.01       0.01    0.01     0.01
# TT             1.0     0.94      0.37      0.37       0.37    0.27     0.27
# bbWW300        1.0     0.93      0.40      0.40       0.40    0.01     0.01
# bbZZ300        1.0     0.94      0.35      0.35       0.35    0.30     0.30
# bbZZ900        1.0     0.94      0.41      0.41       0.41    0.34     0.34
#
#          hhMt cut  analysis cuts
# bbWW900      0.01           0.01
# DY2J         0.01           0.01
# TT           0.27           0.23
# bbWW300      0.01           0.01
# bbZZ300      0.30           0.25
# bbZZ900      0.34           0.31

# %%
dict_effs_muons_VTC={'DY1J': [100.0,
          100.0,
          21.93330106532355,
          13.503682866166033,
          12.580210764416373,
          0.05654888843096004,
          0.056309274496930545,
          0.056309274496930545,
          0.053433907288576644,
          0.053433907288576644,
          0.053433907288576644,
          0.04408896386142647],
 'DY2J': [100.0,
          100.0,
          55.83032848121008,
          35.26481777605033,
          32.91958966429447,
          0.31023733930994374,
          0.3101669268407404,
          0.3101669268407404,
          0.2980559821377648,
          0.2980559821377648,
          0.2980559821377648,
          0.25616056296177375],
 'TT': [100.0,
        100.0,
        5.564233286928243,
        3.049593454162063,
        2.8650325535984646,
        1.1294776127042638,
        1.1294191147960027,
        1.1294191147960027,
        0.8346286557658414,
        0.8346286557658414,
        0.8346286557658414,
        0.6980652889304311],
 'bbWW300': [100.0,
             93.43843446004769,
             15.54941519361066,
             7.838108936750066,
             7.307241000794883,
             3.140732048904198,
             3.140732048904198,
             3.140732048904198,
             0.1239638139217987,
             0.1239638139217987,
             0.1239638139217987,
             0.0955751542450509],
 'bbWW900': [100.0,
             94.51026221605434,
             11.335914104156014,
             5.2560075962311,
             4.949236724855744,
             1.8260170915199767,
             1.8260170915199767,
             1.8260170915199767,
             0.06719742896793514,
             0.06719742896793514,
             0.06719742896793514,
             0.04966766488934336],
 'bbZZ300': [100.0,
             100.0,
             52.30693080975334,
             31.475610762141585,
             29.706669180818594,
             11.072089378100952,
             11.072089378100952,
             11.072089378100952,
             9.364430249961698,
             9.364430249961698,
             9.364430249961698,
             7.779336028189928],
 'bbZZ900': [100.0,
             100.0,
             52.95075673852096,
             31.561987412896546,
             29.588999662637708,
             12.79417410220914,
             12.79417410220914,
             12.79417410220914,
             10.591430997778062,
             10.591430997778062,
             10.591430997778062,
             9.616570305138376]}

names = [
            "skimming",
            "splitSignal",
            "VHbb preselection",
            "decayType",
            "trigger",
            ">=b-jets",
            "Hbb mass",
            "2 leptons",
            "Z mass",
            "MET cut",
            "hhMt cut",
            "analysis cuts" #"final bin"                                                               
            ]
df = pd.DataFrame.from_dict(dict_effs_muons_VTC, orient='index')
df.columns=names
df.round(2)
#df_renorm = df.drop(columns=['skimming', 'splitSignal', 'VHbb preselection'])

df_renorm = df.drop(columns=['skimming', 'splitSignal', 'MET cut'],
                   index=['DY1J', 'DY2J', 'TT', 'bbWW300', 'bbWW900'])
#df_renorm = df_renorm.div(df_renorm['decayType'], axis=0)
df_renorm = df_renorm.div(df_renorm['VHbb preselection'], axis=0)
df_renorm.rename(columns={'VHbb preselection':'leptonic decays', 'decayType':'mm channel'}, inplace=True)
df_renorm.round(3)
# Out:
#          leptonic decays  mm channel  trigger  >=b-jets  Hbb mass  2 leptons  \
# bbZZ300              1.0       0.602    0.568     0.212     0.212      0.212
# bbZZ900              1.0       0.596    0.559     0.242     0.242      0.242
#
#          Z mass  hhMt cut  analysis cuts
# bbZZ300   0.179     0.179          0.149
# bbZZ900   0.200     0.200          0.182

# %%
import pandas as pd
import numpy as np

# %%
dict_effs_eles_VTC_BulkGraviton={'bbZZ300': [84853.0,
             84853.0,
             84853.0,
             64033.0,
             44515.0,
             44338.0,
             41425.0,
             28120.0,
             28120.0,
             9483.0,
             8876.0,
             3295.0,
             3295.0,
             3295.0,
             2848.0,
             2848.0,
             2848.0,
             2261.0,
             2256.0],
 'bbZZ900': [171922.0,
             171922.0,
             171922.0,
             129312.0,
             91240.0,
             91033.0,
             86357.0,
             74865.0,
             74865.0,
             28902.0,
             27207.0,
             11675.0,
             11675.0,
             11675.0,
             9517.0,
             9517.0,
             9517.0,
             8041.0,
             8034.0]}

names = ['no cut', 'splitSignal', 'inclusive >=2 leptons', 'selLeptons pdg ID 11 or 13', 'mva ID', 'ocsf and leading pt', 'eta gap',
                 'iso cut', 'manual preselection', '0 or 1 vType', 'trigger', '>=2b-jets', 'Hbb loose',  '2leps', 'Z mass loose',
                 'met>0', 'hhMt>100', '90<Hbb<150', '76<Z<106']


df = pd.DataFrame.from_dict(dict_effs_eles_VTC_BulkGraviton, orient='index')
df.columns=names
df.round(2)
#df_renorm = df.drop(columns=['skimming', 'splitSignal', 'VHbb preselection'])

#df_renorm = df.drop(columns=['skimming', 'splitSignal', 'MET cut'], index=['DY1J', 'DY2J', 'TT', 'bbWW300', 'bbWW900'])
#df_renorm = df_renorm.div(df_renorm['decayType'], axis=0)
#df_renorm = df_renorm.div(df_renorm['VHbb preselection'], axis=0)
#df_renorm.rename(columns={'VHbb preselection':'leptonic decays', 'decayType':'mm channel'}, inplace=True)
#df_renorm.round(3)
# Out:
#            no cut  splitSignal  inclusive >=2 leptons  \
# bbZZ300   84853.0      84853.0                84853.0
# bbZZ900  171922.0     171922.0               171922.0
#
#          selLeptons pdg ID 11 or 13   mva ID  ocsf and leading pt  eta gap  \
# bbZZ300                     64033.0  44515.0              44338.0  41425.0
# bbZZ900                    129312.0  91240.0              91033.0  86357.0
#
#          iso cut  manual preselection  0 or 1 vType  trigger  >=2b-jets  \
# bbZZ300  28120.0              28120.0        9483.0   8876.0     3295.0
# bbZZ900  74865.0              74865.0       28902.0  27207.0    11675.0
#
#          Hbb loose    2leps  Z mass loose   met>0  hhMt>100  90<Hbb<150  \
# bbZZ300     3295.0   3295.0        2848.0  2848.0    2848.0      2261.0
# bbZZ900    11675.0  11675.0        9517.0  9517.0    9517.0      8041.0
#
#          76<Z<106
# bbZZ300    2256.0
# bbZZ900    8034.0

# %%
dict_effs_muons_VTC_BulkGraviton={'bbZZ300': [84853.0,
             84853.0,
             84853.0,
             64033.0,
             44515.0,
             44338.0,
             41425.0,
             28120.0,
             28120.0,
             18637.0,
             17628.0,
             6682.0,
             6682.0,
             6682.0,
             5711.0,
             5711.0,
             5711.0,
             4512.0,
             4511.0],
 'bbZZ900': [171922.0,
             171922.0,
             171922.0,
             129312.0,
             91240.0,
             91033.0,
             86357.0,
             74865.0,
             74865.0,
             45963.0,
             43031.0,
             18707.0,
             18707.0,
             18707.0,
             15561.0,
             15561.0,
             15561.0,
             12972.0,
             12963.0]}

names = ['no cut', 'splitSignal', 'inclusive >=2 leptons', 'selLeptons pdg ID 11 or 13', 'mva ID', 'ocsf and leading pt', 'eta gap',
                 'iso cut', 'manual preselection', '0 or 1 vType', 'trigger', '>=2b-jets', 'Hbb loose',  '2leps', 'Z mass loose',
                 'met>0', 'hhMt>100', '90<Hbb<150', '76<Z<106']


df = pd.DataFrame.from_dict(dict_effs_muons_VTC_BulkGraviton, orient='index')
df.columns=names
df.round(2)
#df_renorm = df #df.drop(columns=['skimming', 'splitSignal', 'VHbb preselection'])

#df_renorm = df.drop(columns=['skimming', 'splitSignal', 'MET cut'], index=['DY1J', 'DY2J', 'TT', 'bbWW300', 'bbWW900'])
#df_renorm = df_renorm.div(df_renorm['no cut'], axis=0)
#df_renorm = df_renorm.div(df_renorm['VHbb preselection'], axis=0)
#df_renorm.rename(columns={'VHbb preselection':'leptonic decays', 'decayType':'mm channel'}, inplace=True)
#df_renorm.round(3)
# Out:
#            no cut  splitSignal  inclusive >=2 leptons  \
# bbZZ300   84853.0      84853.0                84853.0
# bbZZ900  171922.0     171922.0               171922.0
#
#          selLeptons pdg ID 11 or 13   mva ID  ocsf and leading pt  eta gap  \
# bbZZ300                     64033.0  44515.0              44338.0  41425.0
# bbZZ900                    129312.0  91240.0              91033.0  86357.0
#
#          iso cut  manual preselection  0 or 1 vType  trigger  >=2b-jets  \
# bbZZ300  28120.0              28120.0       18637.0  17628.0     6682.0
# bbZZ900  74865.0              74865.0       45963.0  43031.0    18707.0
#
#          Hbb loose    2leps  Z mass loose    met>0  hhMt>100  90<Hbb<150  \
# bbZZ300     6682.0   6682.0        5711.0   5711.0    5711.0      4512.0
# bbZZ900    18707.0  18707.0       15561.0  15561.0   15561.0     12972.0
#
#          76<Z<106
# bbZZ300    4511.0
# bbZZ900   12963.0

# %%
df_renorm = df
df_renorm = df_renorm.div(df_renorm['no cut'], axis=0)
df_renorm.round(3)
# Out:
#          no cut  splitSignal  inclusive >=2 leptons  \
# bbZZ300     1.0          1.0                    1.0
# bbZZ900     1.0          1.0                    1.0
#
#          selLeptons pdg ID 11 or 13  mva ID  ocsf and leading pt  eta gap  \
# bbZZ300                       0.755   0.525                0.523    0.488
# bbZZ900                       0.752   0.531                0.530    0.502
#
#          iso cut  manual preselection  0 or 1 vType  trigger  >=2b-jets  \
# bbZZ300    0.331                0.331         0.220    0.208      0.079
# bbZZ900    0.435                0.435         0.267    0.250      0.109
#
#          Hbb loose  2leps  Z mass loose  met>0  hhMt>100  90<Hbb<150  76<Z<106
# bbZZ300      0.079  0.079         0.067  0.067     0.067       0.053     0.053
# bbZZ900      0.109  0.109         0.091  0.091     0.091       0.075     0.075
