# %%
arr = [0,1,4,2,6,4,2,4,5]
n = len(arr)
for i in range(n-1, -1, -1):
    print arr[i]
# Out:
# 5
# 4
# 2
# 4
# 6
# 2
# 4
# 1
# 0

# %%
# Python program for implementation of heap Sort 
  
# To heapify subtree rooted at index i. 
# n is size of heap 
def heapify(arr, n, i): 
    print 'n', n
    print 'heapifying', i
    if i<n:
        print "arr[i]", arr[i]
        print arr
        print
    largest = i # Initialize largest as root 
    l = 2 * i + 1     # left = 2*i + 1 
    r = 2 * i + 2     # right = 2*i + 2 
  
    # See if left child of root exists and is 
    # greater than root 
    if l < n and arr[i] < arr[l]: 
        largest = l 
  
    # See if right child of root exists and is 
    # greater than root 
    if r < n and arr[largest] < arr[r]: 
        largest = r 
  
    # Change root, if needed 
    if largest != i: 
        arr[i],arr[largest] = arr[largest],arr[i] # swap 
  
        # Heapify the root. 
        heapify(arr, n, largest) 
  
# The main function to sort an array of given size 
def heapSort(arr): 
    n = len(arr) 
    print 'before building heap'
    print 
    # Build a maxheap. 
    for i in range(n-1, -1, -1): 
        heapify(arr, n, i) 
  
    print
    print 'work with array'
    print arr
    print
    # One by one extract elements 
    for i in range(n-1, 0, -1): 
        print arr
        arr[i], arr[0] = arr[0], arr[i] # swap 
        heapify(arr, i, 0) 
  
# Driver code to test above 
arr = [ 1, 5, 21,  4, 99, 3, 55, 7] 
heapSort(arr) 
n = len(arr) 
print ("Sorted array is") 
for i in range(n): 
    print ("%d" %arr[i]), 
# This code is contributed by Mohit Kumra
# Out:
# before building heap
#
# n 8
# heapifying 7
# arr[i] 7
# [1, 5, 21, 4, 99, 3, 55, 7]
#
# n 8
# heapifying 6
# arr[i] 55
# [1, 5, 21, 4, 99, 3, 55, 7]
#
# n 8
# heapifying 5
# arr[i] 3
# [1, 5, 21, 4, 99, 3, 55, 7]
#
# n 8
# heapifying 4
# arr[i] 99
# [1, 5, 21, 4, 99, 3, 55, 7]
#
# n 8
# heapifying 3
# arr[i] 4
# [1, 5, 21, 4, 99, 3, 55, 7]
#
# n 8
# heapifying 7
# arr[i] 4
# [1, 5, 21, 7, 99, 3, 55, 4]
#
# n 8
# heapifying 2
# arr[i] 21
# [1, 5, 21, 7, 99, 3, 55, 4]
#
# n 8
# heapifying 6
# arr[i] 21
# [1, 5, 55, 7, 99, 3, 21, 4]
#
# n 8
# heapifying 1
# arr[i] 5
# [1, 5, 55, 7, 99, 3, 21, 4]
#
# n 8
# heapifying 4
# arr[i] 5
# [1, 99, 55, 7, 5, 3, 21, 4]
#
# n 8
# heapifying 0
# arr[i] 1
# [1, 99, 55, 7, 5, 3, 21, 4]
#
# n 8
# heapifying 1
# arr[i] 1
# [99, 1, 55, 7, 5, 3, 21, 4]
#
# n 8
# heapifying 3
# arr[i] 1
# [99, 7, 55, 1, 5, 3, 21, 4]
#
# n 8
# heapifying 7
# arr[i] 1
# [99, 7, 55, 4, 5, 3, 21, 1]
#
#
# work with array
# [99, 7, 55, 4, 5, 3, 21, 1]
#
# ...

# %%
graph = {'A': set(['B', 'C']),
         'B': set(['A', 'D', 'E']),
         'C': set(['A', 'F']),
         'D': set(['B']),
         'E': set(['B', 'F']),
         'F': set(['C', 'E'])}

# %%
def dfs(graph, start):
    visited, stack = set(), [start]
    while stack:
        print 'stack before', stack
        vertex = stack.pop()
        print 'stack after', stack

        if vertex not in visited:
            visited.add(vertex)
            print 'visited', visited
            print 'graph[vertex]', graph[vertex]
            stack.extend(graph[vertex] - visited)
            print 'stack modified', stack
        print 
    return visited

dfs(graph, 'A')
# Out:
# stack before ['A']
# stack after []
# visited set(['A'])
# graph[vertex] set(['C', 'B'])
# stack modified ['C', 'B']
#
# stack before ['C', 'B']
# stack after ['C']
# visited set(['A', 'B'])
# graph[vertex] set(['A', 'E', 'D'])
# stack modified ['C', 'E', 'D']
#
# stack before ['C', 'E', 'D']
# stack after ['C', 'E']
# visited set(['A', 'B', 'D'])
# graph[vertex] set(['B'])
# stack modified ['C', 'E']
#
# stack before ['C', 'E']
# stack after ['C']
# visited set(['A', 'B', 'E', 'D'])
# graph[vertex] set(['B', 'F'])
# stack modified ['C', 'F']
#
# stack before ['C', 'F']
# stack after ['C']
# visited set(['A', 'B', 'E', 'D', 'F'])
# graph[vertex] set(['C', 'E'])
# stack modified ['C', 'C']
#
# stack before ['C', 'C']
# stack after ['C']
# visited set(['A', 'C', 'B', 'E', 'D', 'F'])
# graph[vertex] set(['A', 'F'])
# stack modified ['C']
#
# stack before ['C']
# stack after []
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %%
def dfs(graph, start, visited=None):
    if visited is None:
        visited = set()
    visited.add(start)
    print 'start', start
    print 'graph[start]', graph[start]
    print 'visited', visited
    for nxt in graph[start] - visited:
        dfs(graph, nxt, visited)
    return visited

dfs(graph, 'A')
# Out:
# start A
# graph[start] set(['C', 'B'])
# visited set(['A'])
# start C
# graph[start] set(['A', 'F'])
# visited set(['A', 'C'])
# start F
# graph[start] set(['C', 'E'])
# visited set(['A', 'C', 'F'])
# start E
# graph[start] set(['B', 'F'])
# visited set(['A', 'C', 'E', 'F'])
# start B
# graph[start] set(['A', 'E', 'D'])
# visited set(['A', 'C', 'B', 'E', 'F'])
# start D
# graph[start] set(['B'])
# visited set(['A', 'C', 'B', 'E', 'D', 'F'])
# start B
# graph[start] set(['A', 'E', 'D'])
# visited set(['A', 'C', 'B', 'E', 'D', 'F'])
# {'A', 'B', 'C', 'D', 'E', 'F'}

# %%
def dfs_paths(graph, start, goal):
    stack = [(start, [start])]
    while stack:
        print 'stack is', stack

        (vertex, path) = stack.pop()
        print 'stack becomes', stack

        print 'vertex', vertex
        print 'path', path
        print 'graph[vertex]', graph[vertex]

        for nxt in graph[vertex] - set(path):
            print 'nxt', nxt
            if nxt == goal:
                print 'voila', path + [nxt]
                yield path + [nxt]
            else:
                stack.append((nxt, path + [nxt]))
                #return
        print

list(dfs_paths(graph, 'A', 'F'))
# Out:
# stack is [('A', ['A'])]
# stack becomes []
# vertex A
# path ['A']
# graph[vertex] set(['C', 'B'])
# nxt C
# nxt B
#
# stack is [('C', ['A', 'C']), ('B', ['A', 'B'])]
# stack becomes [('C', ['A', 'C'])]
# vertex B
# path ['A', 'B']
# graph[vertex] set(['A', 'E', 'D'])
# nxt E
# nxt D
#
# stack is [('C', ['A', 'C']), ('E', ['A', 'B', 'E']), ('D', ['A', 'B', 'D'])]
# stack becomes [('C', ['A', 'C']), ('E', ['A', 'B', 'E'])]
# vertex D
# path ['A', 'B', 'D']
# graph[vertex] set(['B'])
#
# stack is [('C', ['A', 'C']), ('E', ['A', 'B', 'E'])]
# stack becomes [('C', ['A', 'C'])]
# vertex E
# path ['A', 'B', 'E']
# graph[vertex] set(['B', 'F'])
# nxt F
# voila ['A', 'B', 'E', 'F']
#
# stack is [('C', ['A', 'C'])]
# stack becomes []
# vertex C
# path ['A', 'C']
# graph[vertex] set(['A', 'F'])
# nxt F
# voila ['A', 'C', 'F']
# [['A', 'B', 'E', 'F'], ['A', 'C', 'F']]

# %%
def bfs(graph, start):
    visited, queue = set(), [start]
    while queue:
        print 'queue is ', queue
        vertex = queue.pop(0)
        print 'queue then is ', queue

        if vertex not in visited:
            visited.add(vertex)
            print 'vertex', vertex
            print 'visited', visited
            print 'graph[vertex]', graph[vertex]
            queue.extend(graph[vertex] - visited)
            print 'queue modified ', queue
        print
        
    return visited

bfs(graph, 'A')
# Out:
# queue is  ['A']
# queue then is  []
# vertex A
# visited set(['A'])
# graph[vertex] set(['C', 'B'])
# queue modified  ['C', 'B']
#
# queue is  ['C', 'B']
# queue then is  ['B']
# vertex C
# visited set(['A', 'C'])
# graph[vertex] set(['A', 'F'])
# queue modified  ['B', 'F']
#
# queue is  ['B', 'F']
# queue then is  ['F']
# vertex B
# visited set(['A', 'C', 'B'])
# graph[vertex] set(['A', 'E', 'D'])
# queue modified  ['F', 'E', 'D']
#
# queue is  ['F', 'E', 'D']
# queue then is  ['E', 'D']
# vertex F
# visited set(['A', 'C', 'B', 'F'])
# graph[vertex] set(['C', 'E'])
# queue modified  ['E', 'D', 'E']
#
# queue is  ['E', 'D', 'E']
# queue then is  ['D', 'E']
# vertex E
# visited set(['A', 'C', 'B', 'E', 'F'])
# graph[vertex] set(['B', 'F'])
# queue modified  ['D', 'E']
#
# queue is  ['D', 'E']
# queue then is  ['E']
# vertex D
# visited set(['A', 'C', 'B', 'E', 'D', 'F'])
# graph[vertex] set(['B'])
# queue modified  ['E']
#
# queue is  ['E']
# queue then is  []
# ...

# %%
def bfs_paths(graph, start, goal):
    queue = [(start, [start])]
    while queue:
        print 'queue is ', queue
        (vertex, path) = queue.pop(0)
        
        print 'queue then is ', queue
        print 'path', path
        print 'vertex', vertex
        print 'graph[vertex]', graph[vertex]
        for next in graph[vertex] - set(path):
            print 'next', next
            
            if next == goal:
                print 'voila', path + [next]
                yield path + [next]
            else:
                queue.append((next, path + [next]))
                print 'modified queue', (next, path + [next])
        print 


list(bfs_paths(graph, 'A', 'F'))
# Out:
# queue is  [('A', ['A'])]
# queue then is  []
# path ['A']
# vertex A
# graph[vertex] set(['C', 'B'])
# next C
# modified queue ('C', ['A', 'C'])
# next B
# modified queue ('B', ['A', 'B'])
#
# queue is  [('C', ['A', 'C']), ('B', ['A', 'B'])]
# queue then is  [('B', ['A', 'B'])]
# path ['A', 'C']
# vertex C
# graph[vertex] set(['A', 'F'])
# next F
# voila ['A', 'C', 'F']
#
# queue is  [('B', ['A', 'B'])]
# queue then is  []
# path ['A', 'B']
# vertex B
# graph[vertex] set(['A', 'E', 'D'])
# next E
# modified queue ('E', ['A', 'B', 'E'])
# next D
# modified queue ('D', ['A', 'B', 'D'])
#
# queue is  [('E', ['A', 'B', 'E']), ('D', ['A', 'B', 'D'])]
# queue then is  [('D', ['A', 'B', 'D'])]
# path ['A', 'B', 'E']
# vertex E
# graph[vertex] set(['B', 'F'])
# next F
# voila ['A', 'B', 'E', 'F']
#
# queue is  [('D', ['A', 'B', 'D'])]
# queue then is  []
# path ['A', 'B', 'D']
# vertex D
# graph[vertex] set(['B'])
# [['A', 'C', 'F'], ['A', 'B', 'E', 'F']]

# %%
def shortest_path(graph, start, goal):
    try:
        return next(bfs_paths(graph, start, goal))
    except StopIteration:
        return None

shortest_path(graph, 'A', 'E')
# Out:
# queue is  [('A', ['A'])]
# queue then is  []
# path ['A']
# vertex A
# graph[vertex] set(['C', 'B'])
# next C
# modified queue ('C', ['A', 'C'])
# next B
# modified queue ('B', ['A', 'B'])
#
# queue is  [('C', ['A', 'C']), ('B', ['A', 'B'])]
# queue then is  [('B', ['A', 'B'])]
# path ['A', 'C']
# vertex C
# graph[vertex] set(['A', 'F'])
# next F
# modified queue ('F', ['A', 'C', 'F'])
#
# queue is  [('B', ['A', 'B']), ('F', ['A', 'C', 'F'])]
# queue then is  [('F', ['A', 'C', 'F'])]
# path ['A', 'B']
# vertex B
# graph[vertex] set(['A', 'E', 'D'])
# next E
# voila ['A', 'B', 'E']
# ['A', 'B', 'E']
