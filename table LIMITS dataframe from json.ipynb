# %%
import pickle
import pprint
with open ('combinedCards_limits.txt', 'rb') as fp:  
    print 'inside reading'
    itemlist = pickle.load(fp)                                                                                                          
print 'itemlist'
pprint.pprint(itemlist)
# Out:
# inside reading
# itemlist
# [([u'299.1333', u'407.8568', u'589.0625', u'875.5220', u'1279.7313'], 250),
#  ([u'299.8352', u'407.1236', u'585.9375', u'870.8773', u'1272.9424'], 260),
#  ([u'275.0488', u'373.4680', u'537.5000', u'801.0273', u'1172.1648'], 270),
#  ([u'222.2778', u'301.8143', u'434.3750', u'645.6104', u'943.6746'], 300),
#  ([u'157.1045', u'213.0163', u'309.3750', u'464.7559', u'687.8848'], 350),
#  ([u'59.4925', u'81.6814', u'119.9219', u'182.0637', u'271.9377'], 400),
#  ([u'30.1575', u'42.3201', u'63.2812', u'97.8384', u'148.8287'], 450),
#  ([u'30.5695', u'42.1505', u'62.1094', u'94.7887', u'142.5621'], 451),
#  ([u'17.1387', u'23.9674', u'36.5625', u'58.1320', u'91.2878'], 500),
#  ([u'9.6429', u'13.4492', u'20.2344', u'31.6874', u'48.9400'], 550),
#  ([u'6.0997', u'8.5215', u'12.6953', u'19.7799', u'30.5158'], 600),
#  ([u'4.9402', u'7.1035', u'11.0938', u'18.2574', u'29.5025'], 650),
#  ([u'4.5273', u'6.4788', u'10.0781', u'16.4253', u'26.5354'], 700),
# ...

# %%
def returnLimits(list_of_tuples):
    return [round(float(x[0][2]),1) for x in list_of_tuples]

from array import array
#print returnLimits(itemlist)


mass = array('d', [250.0, 260.0, 270.0, 300.0, 350.0, 400.0, 450.0, 451.0, 500.0, 550.0, 600.0, 650.0, 700.0, 750.0, 800.0, 900.0, 1000.0])
exp  = array('d', [589.0625, 585.9375, 537.5, 434.375, 309.375, 119.921875, 63.28124999999999, 62.109375, 36.5625, 20.234375, 12.6953125, 11.09375, 10.078125, 8.828125, 6.54296875, 4.8046875, 4.23828125])
obs  =  array('d', [253.52320159523111, 272.2142705679539, 274.39137872002823, 379.9523103156983, 330.5832879927235, 90.44215852752016, 59.766252438272176, 87.11149963378786, 30.96093499311799, 14.471096999115861, 9.802208829065435, 18.540281553709782, 16.122016732602532, 13.683178761163715, 10.115019120371553, 8.101185890850545, 5.786240262307295])



import pandas as pd
import collections
df = pd.DataFrame(collections.OrderedDict({"Mass, GeV": masses, "Observed Limit, pb": obs, "Expected Limit, pb": exp}))
print df.round(1).to_latex(index=False)#to remove index
# Out:
# \begin{tabular}{rrr}
# \toprule
#  Mass, GeV &  Observed Limit, pb &  Expected Limit, pb \\
# \midrule
#        250 &               253.5 &               589.1 \\
#        260 &               272.2 &               585.9 \\
#        270 &               274.4 &               537.5 \\
#        300 &               380.0 &               434.4 \\
#        350 &               330.6 &               309.4 \\
#        400 &                90.4 &               119.9 \\
#        450 &                59.8 &                63.3 \\
#        451 &                87.1 &                62.1 \\
#        500 &                31.0 &                36.6 \\
#        550 &                14.5 &                20.2 \\
#        600 &                 9.8 &                12.7 \\
#        650 &                18.5 &                11.1 \\
#        700 &                16.1 &                10.1 \\
#        750 &                13.7 &                 8.8 \\
# ...

# %%
# GRAVITON
from array import array

mass = array('d', [250.0, 260.0, 270.0, 300.0, 350.0, 400.0, 450.0, 451.0, 500.0, 550.0, 600.0, 650.0, 700.0, 750.0, 800.0, 900.0, 1000.0])
exp = array('d', [589.0625, 585.9375, 537.5, 434.375, 309.375, 119.921875, 63.28124999999999, 62.109375, 36.5625, 20.234375, 12.6953125, 11.09375, 10.078125, 8.828125, 6.54296875, 4.8046875, 4.23828125])
obs =  array('d', [253.52320159523111, 272.2142705679539, 274.39137872002823, 379.9523103156983, 330.5832879927235, 90.44215852752016, 59.766252438272176, 87.11149963378786, 30.96093499311799, 14.471096999115861, 9.802208829065435, 18.540281553709782, 16.122016732602532, 13.683178761163715, 10.115019120371553, 8.101185890850545, 5.786240262307295])

import pandas as pd
import collections
df = pd.DataFrame(collections.OrderedDict({"Mass, GeV": mass, "Observed Limit, pb": obs, "Expected Limit, pb": exp}))
print df.round(1).to_latex(index=False)#to remove index
# Out:
# \begin{tabular}{rrr}
# \toprule
#  Mass, GeV &  Observed Limit, pb &  Expected Limit, pb \\
# \midrule
#      250.0 &               253.5 &               589.1 \\
#      260.0 &               272.2 &               585.9 \\
#      270.0 &               274.4 &               537.5 \\
#      300.0 &               380.0 &               434.4 \\
#      350.0 &               330.6 &               309.4 \\
#      400.0 &                90.4 &               119.9 \\
#      450.0 &                59.8 &                63.3 \\
#      451.0 &                87.1 &                62.1 \\
#      500.0 &                31.0 &                36.6 \\
#      550.0 &                14.5 &                20.2 \\
#      600.0 &                 9.8 &                12.7 \\
#      650.0 &                18.5 &                11.1 \\
#      700.0 &                16.1 &                10.1 \\
#      750.0 &                13.7 &                 8.8 \\
# ...

# %%
#RADION
from array import array

mass = array('d', [250.0, 260.0, 270.0, 300.0, 350.0, 400.0, 450.0, 451.0, 500.0, 550.0, 600.0, 650.0, 700.0, 750.0, 800.0, 900.0, 1000.0])
exp = array('d', [297.65625, 410.9375, 470.3125, 496.875, 496.875, 171.09375, 82.03125, 92.1875, 54.375, 28.515625, 19.609375, 17.1875, 12.03125, 10.3515625, 9.8046875, 5.60546875, 4.53125])
obs = array('d', [107.28371005961692, 170.77294184904787, 206.95778139443652, 451.69775663635806, 532.6329122361457, 155.6984248209337, 89.34818873982849, 126.71870723366408, 35.96294808505278, 18.70400653123663, 13.166226584078801, 24.5878123015589, 16.43763058908431, 13.901923446693768, 12.583765588783283, 6.920223961394254, 5.736882604388354])

import pandas as pd
import collections
df = pd.DataFrame(collections.OrderedDict({"Mass, GeV": mass, "Observed Limit, pb": obs, "Expected Limit, pb": exp}))
print df.round(1).to_latex(index=False)#to remove index
# Out:
# \begin{tabular}{rrr}
# \toprule
#  Mass, GeV &  Observed Limit, pb &  Expected Limit, pb \\
# \midrule
#      250.0 &               107.3 &               297.7 \\
#      260.0 &               170.8 &               410.9 \\
#      270.0 &               207.0 &               470.3 \\
#      300.0 &               451.7 &               496.9 \\
#      350.0 &               532.6 &               496.9 \\
#      400.0 &               155.7 &               171.1 \\
#      450.0 &                89.3 &                82.0 \\
#      451.0 &               126.7 &                92.2 \\
#      500.0 &                36.0 &                54.4 \\
#      550.0 &                18.7 &                28.5 \\
#      600.0 &                13.2 &                19.6 \\
#      650.0 &                24.6 &                17.2 \\
#      700.0 &                16.4 &                12.0 \\
#      750.0 &                13.9 &                10.4 \\
# ...
